# %% [markdown]
# # CodingX 2019/7/9

# %% [markdown]
# ## E1

# %%
score = 70

# %%
if score<70:
    print("D")
elif score >= 70:
    print("D")
elif score >= 80:
    print("B")
elif score >= 90:
    print("A")
# Out:
# D

# %% [markdown]
# ## E2

# %%
y = int(input("Enter year : "))
if (y%4 !=0) or (y%100 == 0 and y%400 != 0):
    print("平年")
elif (y%400 ==0) or (y%4 == 0 and y%100 != 0):
    print("閏年")
# Out:
# Enter year : 21
# 平年

# %% [markdown]
# ##E3

# %%
special = '16256802'   #特別獎
specify = '33378146'   #特獎
headers = '92040881'   #頭獎 最左邊的號碼
extra_1 = '998'        #增開六獎 1
extra_2 = '741'        #增開六獎 2
extra_3 = '833'        #增開六獎 3
extra_4 = '732'        #增開六獎 4

# %%
value = 0
key = input("Enter the key : ")

if key == special:
    value = value + 10000000
elif key == specify:
    value = value + 2000000
elif key == headers:
    value = value + 200000
elif key[5:] == extra_1:
    value = value + 200
elif key[5:] == extra_2:
    value = value + 200
elif key[5:] == extra_3:
    value = value + 200
elif key[5:] == extra_4:
    value = value + 200


if value !=0:
    print("中獎："+ format(value))
else:
    print("沒中")
# Out:
# Enter the key : 16256998
# 中獎：200
